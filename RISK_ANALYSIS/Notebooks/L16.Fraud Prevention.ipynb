# %%
import pandas as pd
import numpy as np
df_log_in=pd.read_csv('log_in_table.csv')
df_order=pd.read_csv('order_table_50k_v2.csv')
df_transaction_data=pd.read_csv('transaction_data.csv')

# %% [markdown]
# # Application Fraud Prevention

# %%
df_log_in.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50861 entries, 0 to 50860
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      50861 non-null  int64
#  1   log_in_date  50861 non-null  object
#  2   device_id    50861 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB

# %%
#是否存在一个device_id关联多个用户的情况
df_device_cnt=df_log_in.groupby("device_id").agg(user_cnt=("user_id", "size"),
                         ).reset_index()
df_device_fraud=df_device_cnt[df_device_cnt['user_cnt']>2]
df_device_fraud
# Out:
#                                device_id  user_cnt
# 21013  6af890a803027331e93cc4d4d78653999        16

# %%
df_fraud_user_id
# Out:
#        user_id log_in_date                          device_id
# 118      90032   2010/1/22  6af890a803027331e93cc4d4d78653999
# 126      90039  2009/11/25  6af890a803027331e93cc4d4d78653999
# 132      90044   2009/6/19  6af890a803027331e93cc4d4d78653999
# 140      90051   2009/7/19  6af890a803027331e93cc4d4d78653999
# 145      90055  2009/10/19  6af890a803027331e93cc4d4d78653999
# 147      90056   2009/8/27  6af890a803027331e93cc4d4d78653999
# 149      90057    2009/1/9  6af890a803027331e93cc4d4d78653999
# 152      90059  2009/12/10  6af890a803027331e93cc4d4d78653999
# 17043   106153  2009/12/10  6af890a803027331e93cc4d4d78653999
# 17501   106610   2009/2/19  6af890a803027331e93cc4d4d78653999
# 17629   106737    2010/2/2  6af890a803027331e93cc4d4d78653999
# 17717   106824    2009/5/1  6af890a803027331e93cc4d4d78653999
# 37822   126928   2010/1/29  6af890a803027331e93cc4d4d78653999
# 38134   127239    2010/1/3  6af890a803027331e93cc4d4d78653999
# 38139   127243    2009/1/2  6af890a803027331e93cc4d4d78653999
# 38317   127420  2009/12/30  6af890a803027331e93cc4d4d78653999

# %%
#关联欺诈用户到订单表
df_fraud_user_id=df_log_in[df_log_in['device_id']=='6af890a803027331e93cc4d4d78653999']
df_order_2=pd.merge(df_order,df_fraud_user_id,how='left',on='user_id')
df_order_2['fraud_s1']=np.where(df_order_2.device_id.isnull()==False,1,0)

# %%
#套入分析框架
df=df_order_2
df_pivot=df[df['control_group']==0].groupby("fraud_s1").agg(order_cnt=("order_id", "size"),
                         approval_cnt=("order_status", "sum"),
                         fpd30=("fpd30", "sum"),
                         mob3_m2=("mob3_m2", "sum"),
                         principal=("principal", "sum")).reset_index()
df_pivot['fpd30_rate']=df_pivot['fpd30']/df_pivot['approval_cnt']
df_pivot['mob3_m2_rate']=df_pivot['mob3_m2']/df_pivot['approval_cnt']
df_pivot
# Out:
#    fraud_s1  order_cnt  approval_cnt  fpd30  mob3_m2  principal  fpd30_rate  \
# 0         0      44986         27659    105      464   93794300    0.003796
# 1         1         14             6      6        6      17400    1.000000
#
#    mob3_m2_rate
# 0      0.016776
# 1      1.000000

# %% [markdown]
# # Transaction Fraud Prevention
# 1.计算还有多少用户有潜在被盗刷的风险
# 2.计算这些用户潜在被盗刷的金额是多少

# %%
df_transaction_data[' amount ']
# Out:
# 0        45.59
# 1        39.69
# 2        49.76
# 3        49.07
# 4        57.20
#          ...
# 19995    56.38
# 19996    34.93
# 19997    34.18
# 19998    58.91
# 19999    46.59
# Name:  amount , Length: 20000, dtype: float64

# %%
df_transaction_data.columns
# Out:
# Index(['transaction_id', 'user_id', ' amount ', 'pos_id', 'transaction_date'], dtype='object')

# %%
df_transaction_data.describe()
# Out:
#        transaction_id       user_id       amount
# count    20000.000000  20000.000000  20000.000000
# mean     90330.000000  90414.500000     49.849176
# std       5779.623715    288.682207     10.031318
# min      79881.000000  89915.000000     13.170000
# 25%      85350.500000  90164.750000     43.037500
# 50%      90334.500000  90414.500000     49.900000
# 75%      95307.250000  90664.250000     56.600000
# max     100803.000000  90914.000000     85.930000

# %%
#查看投诉用户交易信息
df_transaction_data_fraud=df_transaction_data[(df_transaction_data['user_id']==90559)
|(df_transaction_data['user_id']==90059)
|(df_transaction_data['user_id']==90222)
|(df_transaction_data['user_id']==90745)]
df_transaction_data_fraud
# Out:
#        transaction_id  user_id   amount                           pos_id  \
# 115             80106    90059     50.88  e776843ee6f5ce7768436843ee6f5c
# 131             80676    90059     51.76  d1c5c7351fb08d1c5c735c7351fb08
# 152             81426    90059     59.35  f43c54892fe7ff43c548c54892fe7f
# 186             82559    90059     45.48  42fb5585b82da42fb558b5585b82da
# 264             82765    90059     59.20  b5585b82da42fb5585ba85b82da42f
# ...               ...      ...       ...                             ...
# 19279           96319    90745     45.64  9c6cf15c50de89c6cf19cf15c50de8
# 19466           98482    90745     58.00  d4f6738116b40d4f67326738116b40
# 19530           99184    90745     63.96  f2ed520897f38f2ed520d520897678
# 19618          100127    90745     45.56  c458495175b64c4584958495175b64
# 19624          100285    90745     56.87  8495175b64c45849517b5175b64c45
#
#       transaction_date
# 115         2009-01-03
# 131         2009-01-14
# 152         2009-01-29
# 186         2009-02-20
# 264         2009-02-24
# ...                ...
# 19279       2009-11-08
# 19466       2009-12-21
# 19530       2010-01-04
# 19618       2010-01-25
# 19624       2010-01-28
#
# [80 rows x 5 columns]

# %%
#寻找交易信息共性
df_pos_id=df_transaction_data_fraud.groupby("pos_id").agg(user_id=("user_id", "size"))
df_tmp=df_pos_id[df_pos_id['user_id']>1]
df_tmp
# Out:
#                                 user_id
# pos_id
# f2ed520897f38f2ed520d520897678        4

# %%
#查看明细，还原案件
df_tmp=df_transaction_data_fraud[df_transaction_data_fraud['user_id']==90559]
df_tmp
# Out:
#        transaction_id  user_id   amount                           pos_id  \
# 10407           80590    90559     44.56  789c319db5864789c31fc319db5864
# 10964           81369    90559     41.40  27c68a2a6d50a27c68af68a2a6d50a
# 11037           83590    90559     38.37  c297629920fb5c2976297629920fb5
# 11155           84365    90559     60.43  50a27c68a2a6d50a27c627c68a2a6d
# 11158           85040    90559     33.72  864789c319db5864789c789c319db5
# 11599           87479    90559     61.69  f2ed520897f38f2ed520d520897678
# 11684           87605    90559     38.24  7629920fb5c29762992a9920fb5c29
# 11849           87677    90559     36.13  0ef8c8a528b980ef8c8a8c8a528b98
# 12046           88079    90559     37.63  84511a4d8037684511a911a4d80376
# 12210           88447    90559     43.66  b4974aca03d6fb4974ac74aca03d6f
# 12334           88990    90559     54.01  37684511a4d80376845184511a4d80
# 12891           91439    90559     56.96  7e23f4c8484907e23f4c3f4c848490
# 12956           91512    90559     43.32  3f4c8484907e23f4c84bc8484907e2
# 13465           92324    90559     36.78  866aecf198558866aecfaecf198558
# 13650           94244    90559     50.10  8c8a528b980ef8c8a525a528b980ef
# 13769           94789    90559     50.87  74aca03d6fb4974aca0fca03d6fb49
# 14128           96196    90559     49.37  15aa9f0878b6c15aa9f1a9f0878b6c
# 14243           96968    90559     67.91  423831e6fe576423831e831e6fe576
# 14308           98015    90559     30.62  576423831e6fe5764238423831e6fe
# 14314           99104    90559     46.33  b6c15aa9f0878b6c15aa15aa9f0878
#
#       transaction_date
# 10407       2009-01-02
# 10964       2009-01-17
# 11037       2009-03-03
# 11155       2009-03-19
# 11158       2009-04-01
# 11599       2009-05-19
# 11684       2009-05-21
# 11849       2009-05-23
# 12046       2009-05-31
# 12210       2009-06-08
# 12334       2009-06-19
# 12891       2009-08-08
# 12956       2009-08-09
# 13465       2009-08-26
# 13650       2009-10-01
# 13769       2009-10-12
# 14128       2009-11-09
# 14243       2009-11-25
# 14308       2009-12-16
# 14314       2010-01-07

# %%
#预估损失#找到所有涉及这个posid的交易
df_transaction_data_fraud_all=df_transaction_data[(df_transaction_data['user_id']!=90559)
&(df_transaction_data['user_id']!=90059)
&(df_transaction_data['user_id']!=90222)
&(df_transaction_data['user_id']!=90745)
&(df_transaction_data['pos_id']=='f2ed520897f38f2ed520d520897678')]
display(df_transaction_data_fraud_all)
##user_id 去重计数
print(len(df_transaction_data_fraud_all['user_id'].unique()))
# Out:
#       transaction_id  user_id   amount                           pos_id  \
# 202            80059    89941     54.98  f2ed520897f38f2ed520d520897678
# 586            81155    90653     60.52  f2ed520897f38f2ed520d520897678
# 762            80633    89955     29.62  f2ed520897f38f2ed520d520897678
# 933            81054    90205     44.77  f2ed520897f38f2ed520d520897678
# 1016           81345    90413     62.41  f2ed520897f38f2ed520d520897678
# 1666           81980    90398     36.73  f2ed520897f38f2ed520d520897678
#
#      transaction_date
# 202        2009-01-04
# 586        2009-01-11
# 762        2009-01-15
# 933        2009-01-18
# 1016       2009-01-20
# 1666       2009-02-02
# 6

# %%
df_f_all
# Out:
#        transaction_id_x  user_id   amount _x                        pos_id_x  \
# 0                 80374    90458       45.59  fd15d3183f0b9fd15d315d3183f0b9
# 1                 80673    90756       39.69  727f0374a06a4727f037f0374a06a4
# 2                 80217    90299       49.76  00bc8f466315f00bc8f4c8f466315f
# 3                 80251    90332       49.07  c8b5de39a104fc8b5de35de39a104f
# 4                 80377    90457       57.20  eaa4682ec62ddeaa46824682ec62dd
# ...                 ...      ...         ...                             ...
# 19995            100619    90708       56.38  2ea26b3a2263a2ea26b126b3a2263a
# 19996            100642    90730       34.93  541feac7a1b28541feabfeac7a1b28
# 19997            100771    90858       34.18  75bb9ca0b5a0f75bb9c3b9ca0b5a0f
# 19998            100512    90598       58.91  52b9ccf340b4c52b9cc59ccf340b4c
# 19999            100792    90877       46.59  e5de20ac10ca1e5de20fe20ac10ca1
#
#       transaction_date_x  transaction_id_y   amount _y pos_id_y  \
# 0             2009-01-01               NaN         NaN      NaN
# 1             2009-01-01               NaN         NaN      NaN
# 2             2009-01-01               NaN         NaN      NaN
# 3             2009-01-01               NaN         NaN      NaN
# 4             2009-01-01               NaN         NaN      NaN
# ...                  ...               ...         ...      ...
# 19995         2010-02-04               NaN         NaN      NaN
# 19996         2010-02-04               NaN         NaN      NaN
# 19997         2010-02-04               NaN         NaN      NaN
# 19998         2010-02-04               NaN         NaN      NaN
# 19999         2010-02-04               NaN         NaN      NaN
#
#       transaction_date_y
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 19995                NaN
# 19996                NaN
# 19997                NaN
# 19998                NaN
# 19999                NaN
#
# [20000 rows x 9 columns]

# %%
#预估损失#统计这些用户在交易时间之后所有的金额
df_f_all=pd.merge(df_transaction_data,df_transaction_data_fraud_all
                                             ,how='left',on='user_id')
df_f_all.head()
df_f_all_loss=df_f_all[(df_f_all['transaction_date_y'].isnull()==False)\
             &(df_f_all['transaction_date_y']<df_f_all['transaction_date_x'])]
df_f_all_loss.describe()
# Out:
#        transaction_id_x       user_id   amount _x  transaction_id_y  \
# count        108.000000    108.000000  108.000000        108.000000
# mean       90800.601852  90264.981481   50.716389      81038.601852
# std         5257.187121    260.365989    9.190361        597.016147
# min        81464.000000  89941.000000   29.910000      80059.000000
# 25%        86209.000000  89955.000000   44.195000      80633.000000
# 50%        90706.500000  90398.000000   50.480000      81155.000000
# 75%        95608.250000  90413.000000   57.250000      81345.000000
# max       100368.000000  90653.000000   69.190000      81980.000000
#
#         amount _y
# count  108.000000
# mean    48.317500
# std     12.276577
# min     29.620000
# 25%     36.730000
# 50%     54.980000
# 75%     60.520000
# max     62.410000

# %%
df_f_all_loss[' amount _x'].sum()
# Out:
# 5477.37

# %%
df_f_all_loss
# Out:
#        transaction_id_x  user_id   amount _x                        pos_id_x  \
# 1135              81464    90413       39.62  950f00b0748c9950f006f00b0748c9
# 1552              81673    90205       44.18  69e7e9b06a87469e7e9c7e9b06a874
# 1786              81643    89941       68.07  811f549fc3472811f549f549fc3472
# 1963              81820    89941       50.49  593c79c0cc6bc593c79dc79c0cc6bc
# 2215              82544    90413       48.09  a44d59cb95323a44d59cd59cb95323
# ...                 ...      ...         ...                             ...
# 18255             98126    89955       46.91  a66fa454dbabea66fa45fa454dbabe
# 18381             98252    89955       40.16  c1f43ea1f2efcc1f43eb43ea1f2efc
# 19123             99692    90653       52.79  f88d51c3b58e8f88d51cd51c3b58e8
# 19373             99702    90413       56.84  6b95a5d6764c46b95a535a5d6764c4
# 19799            100368    90653       40.57  864a611f4121b864a611a611f4121b
#
#       transaction_date_x  transaction_id_y   amount _y  \
# 1135          2009-01-22           81345.0       62.41
# 1552          2009-01-30           81054.0       44.77
# 1786          2009-02-04           80059.0       54.98
# 1963          2009-02-07           80059.0       54.98
# 2215          2009-02-13           81345.0       62.41
# ...                  ...               ...         ...
# 18255         2009-12-30           80633.0       29.62
# 18381         2010-01-01           80633.0       29.62
# 19123         2010-01-17           81155.0       60.52
# 19373         2010-01-22           81345.0       62.41
# 19799         2010-02-01           81155.0       60.52
#
#                              pos_id_y transaction_date_y
# 1135   f2ed520897f38f2ed520d520897678         2009-01-20
# 1552   f2ed520897f38f2ed520d520897678         2009-01-18
# 1786   f2ed520897f38f2ed520d520897678         2009-01-04
# 1963   f2ed520897f38f2ed520d520897678         2009-01-04
# 2215   f2ed520897f38f2ed520d520897678         2009-01-20
# ...                               ...                ...
# 18255  f2ed520897f38f2ed520d520897678         2009-01-15
# 18381  f2ed520897f38f2ed520d520897678         2009-01-15
# 19123  f2ed520897f38f2ed520d520897678         2009-01-11
# 19373  f2ed520897f38f2ed520d520897678         2009-01-20
# 19799  f2ed520897f38f2ed520d520897678         2009-01-11
#
# [108 rows x 9 columns]
